# %%
# %matplotlib inline

# %%
# Step 1: Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5

# Step 2: Navigate to YOLOv5 directory and install dependencies
# %cd yolov5
# !pip install -r requirements.txt

# Step 3: Import necessary libraries
import torch
from pathlib import Path
import cv2
import matplotlib.pyplot as plt
from IPython.display import display, Image

# Step 4: Load the YOLOv5 model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /Users/azamsharp/Desktop/machine-learning/yolov5/yolov5
# Requirement already satisfied: gitpython>=3.1.30 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (3.8.4)
# Requirement already satisfied: numpy>=1.23.5 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (4.9.0.80)
# Requirement already satisfied: pillow>=10.3.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (10.4.0)
# Requirement already satisfied: psutil in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (5.9.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (6.0.1)
# Requirement already satisfied: requests>=2.32.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (1.13.0)
# Requirement already satisfied: thop>=0.1.1 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (2.4.0)
# Requirement already satisfied: torchvision>=0.9.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (0.19.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (4.66.5)
# Requirement already satisfied: ultralytics>=8.2.34 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (8.2.78)
# Requirement already satisfied: pandas>=1.1.4 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 27)) (2.2.1)
# Requirement already satisfied: seaborn>=0.11.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 28)) (0.12.2)
# Requirement already satisfied: setuptools>=70.0.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from -r requirements.txt (line 42)) (72.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from gitpython>=3.1.30->-r requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from matplotlib>=3.3->-r requirements.txt (line 6)) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from requests>=2.32.0->-r requirements.txt (line 12)) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from requests>=2.32.0->-r requirements.txt (line 12)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from requests>=2.32.0->-r requirements.txt (line 12)) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from requests>=2.32.0->-r requirements.txt (line 12)) (2024.2.2)
# Requirement already satisfied: filelock in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (4.9.0)
# Requirement already satisfied: sympy in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (1.13.2)
# Requirement already satisfied: networkx in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.3)
# Requirement already satisfied: jinja2 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (3.1.3)
# Requirement already satisfied: fsspec in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from torch>=1.8.0->-r requirements.txt (line 15)) (2024.6.1)
# Requirement already satisfied: py-cpuinfo in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from ultralytics>=8.2.34->-r requirements.txt (line 18)) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from pandas>=1.1.4->-r requirements.txt (line 27)) (2023.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: six>=1.5 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->-r requirements.txt (line 15)) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/azamsharp/Desktop/machine-learning/env/lib/python3.12/site-packages (from sympy->torch>=1.8.0->-r requirements.txt (line 15)) (1.3.0)
# Using cache found in /Users/azamsharp/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-8-16 Python-3.12.3 torch-2.4.0 CPU
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100%|█████████████████████████████████████████████████████████████████████████████| 14.1M/14.1M [00:00<00:00, 45.3MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
from PIL import Image

# %%
import matplotlib.pyplot as plt

image_path = '/Users/azamsharp/Desktop/machine-learning/traffic-light.png'
image = cv2.imread(image_path)

plt.imshow(image)
plt.show()

# %%
# Step 2: Convert the image from BGR to RGB
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(image_rgb)

# %%
plt.show()

# %%
# Step 6: Perform object detection
results = model(image_rgb)

# Step 7: Visualize the results
for _, row in results.pandas().xyxy[0].iterrows():
    cv2.rectangle(image, (int(row['xmin']), int(row['ymin'])), (int(row['xmax']), int(row['ymax'])), (255, 0, 0), 2)
    cv2.putText(image, row['name'], (int(row['xmin']), int(row['ymin'] - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (255, 0, 0), 2)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 10))
plt.imshow(image_rgb)
plt.show()
# Out:
# /Users/azamsharp/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):

# %%
results
# Out:
# YOLOv5 <class 'models.common.Detections'> instance
# image 1/1: 932x1634 8 cars, 5 traffic lights
# Speed: 3.1ms pre-process, 95.1ms inference, 1.7ms NMS per image at shape (1, 3, 384, 640)
